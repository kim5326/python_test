# %% [markdown]
# # Pandas

# %% [markdown]
# - 실행속도 매우 빠름 (C언어, 병렬처리)

# %%
import pandas as pd
import numpy as np

# %%
# 데이터프레임 (DataFrame)

url = 'http://bit.ly/ds01-weight-history'
data = pd.read_csv(url, index_col = '회차')
print(data.shape)   # 몇개의 행과 몇개의 열을 가지고 있는지 확인
data.head()         # 데이터의 상위 5개만 보겠다는 기능
                    # .(콤마) 는 기능을 사용한다는 뜻
# Out:
# (9, 6)
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %% [markdown]
# ## 행렬 검색

# %% [markdown]
# ### 열(컬럼) 검색

# %%
data.head(1)
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남

# %%
data['몸무게']

# 검색은 대괄호 사용
# Out:
# 0    76.4
# 1    75.7
# 2    76.0
# 3     NaN
# 4    76.2
# 5    75.7
# 6     NaN
# 7     NaN
# 8    75.0
# Name: 몸무게, dtype: float64

# %%
cols = ['이름','지점','몸무게']
data[cols]

# 보기 쉬움 -> 습관화 필요


# 바깥 대괄호는 검색할 때 쓰는 대괄호
# 안쪽 대괄호는 리스트의 대괄호
# Out:
#     이름   지점   몸무게
# 0  강성희   강남  76.4
# 1  강성희   강남  75.7
# 2  강성희   강남  76.0
# 3  강성희  여의도   NaN
# 4  강성희  강남구  76.2
# 5  강성희  여의도  75.7
# 6  강성희  여의도   NaN
# 7  강성희  여의도   NaN
# 8  강성희  여의도  75.0

# %%
data.columns
# Out:
# Index(['회차', '이름', '측정일', '몸무게', '단위', '담당', '지점'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %% [markdown]
# # 행(Rows) 검색

# %%
data.head(1)
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남

# %%
data.loc[1]

# loc = locate의 줄임말
# Out:
# 이름            강성희
# 측정일    2019-01-01
# 몸무게          76.4
# 단위             kg
# 담당            김지수
# 지점             강남
# Name: 1, dtype: object

# %%
data.loc[[1,3]]
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 3   강성희  2019-01-03  76.0  kg  김지수  강남

# %%
data[['이름','몸무게', '지점']]

# %%
rows = [1,2,3]
data.loc[rows]
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 2   강성희  2019-01-02  75.7  kg  김지수  강남
# 3   강성희  2019-01-03  76.0  kg  김지수  강남

# %%
rows = [1,2,3]
data.loc[rows]
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 2   강성희  2019-01-02  75.7  kg  김지수  강남
# 3   강성희  2019-01-03  76.0  kg  김지수  강남

# %% [markdown]
# ## 행렬 동시 검색

# %%
data.loc[1, '담당']

# 왼쪽은 행
# 오른쪽은 열
# Out:
# '김지수'

# %%
data.loc[[1,2,3], ['담당', '몸무게']]
# Out:
#      담당   몸무게
# 회차
# 1   김지수  76.4
# 2   김지수  75.7
# 3   김지수  76.0

# %%
data.loc[[1,2,3], ['몸무게']]
# Out:
#      몸무게
# 회차
# 1   76.4
# 2   75.7
# 3   76.0

# %%
idx = [1,2,3]
cols = ['담당', '몸무게']

data.loc[idx,cols]

# 앞에 행, 뒤에 열
# Out:
#      담당   몸무게
# 회차
# 1   김지수  76.4
# 2   김지수  75.7
# 3   김지수  76.0

# %% [markdown]
# # 색인 (Indexing) : 조건부 검색

# %%
data.head(2)
# Out:
#      이름         측정일   몸무게  단위   담당  지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수  강남
# 2   강성희  2019-01-02  75.7  kg  김지수  강남

# %%
data['담당'] == '김지수'
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 담당, dtype: bool

# %%
sum(data['담당'] == '김지수')
# Out:
# 4

# %%
# data['담당'] == '김지수'
data[data['담당']=='김지수']
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data['몸무게']>=76
# Out:
# 회차
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 몸무게, dtype: bool

# %%
data[data['몸무게']>=76]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data['몸무게']>75.5
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: 몸무게, dtype: bool

# %%
data[data['몸무게']>75.5]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도

# %%
data['담당']=='김지수'   data['몸무게']>75.5

# %%
data['담당']=='김지수' &  data['몸무게']>75.5

# & 가 어디까지 잡아야 하는지 모름 => 괄호 넣어줘야 함
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1788         try:
# -> 1789             result = op(x, y)
#    1790         except TypeError:
#
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\ops.py in rand_(left, right)
#     186 def rand_(left, right):
# --> 187     return operator.and_(right, left)
#     188
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1803                 try:
# ...

# %%
(data['담당']=='김지수') &  (data['몸무게']>75.5)
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
data[(data['담당']=='김지수') &  (data['몸무게']>75.5)]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data[(data['담당']=='김지수') | (data['몸무게']>75.5)]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도

# %%
kim = data['담당']=='김지수'

over_weight = (data['몸무게'] > 75.5)

# %%
kim
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: 담당, dtype: bool

# %%
over_weight
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: 몸무게, dtype: bool

# %%
data[kim & over_weight]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data[kim]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data[kim, '담당']

# 행렬 동시 검색 시 loc 사용 필수
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-7ff55abc4045> in <module>
# ----> 1 data[kim, '담당']
#
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\ProgramData\Anaconda33\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# ...

# %%
data.loc[kim, '담당']
# Out:
# 회차
# 1    김지수
# 2    김지수
# 3    김지수
# 5    김지수
# Name: 담당, dtype: object

# %%
data.loc[kim, ['담당','몸무게']]
# Out:
#      담당   몸무게
# 회차
# 1   김지수  76.4
# 2   김지수  75.7
# 3   김지수  76.0
# 5   김지수  76.2

# %%
cols = ['담당', '몸무게']
data.loc[kim, cols]
# Out:
#      담당   몸무게
# 회차
# 1   김지수  76.4
# 2   김지수  75.7
# 3   김지수  76.0
# 5   김지수  76.2

# %%
# NaN = Not a Number = 빈 값 = null !='NaN'

data.head()
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data['몸무게'].isnull()
# Out:
# 회차
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# 7     True
# 8     True
# 9    False
# Name: 몸무게, dtype: bool

# %%
sum(data['몸무게'].isnull())
# Out:
# 3

# %%
data[data['몸무게'].isnull()]
# Out:
#      이름         측정일  몸무게  단위   담당   지점
# 회차
# 4   강성희  2019-01-04  NaN  kg  최재우  여의도
# 7   강성희  2019-01-07  NaN  kg  최재우  여의도
# 8   강성희  2019-01-08  NaN  kg  김민철  여의도

# %%
data.loc[data['몸무게'].isnull(),'담당']
# Out:
# 회차
# 4    최재우
# 7    최재우
# 8    김민철
# Name: 담당, dtype: object

# %%
data.loc[data['몸무게'].isnull(),['담당','몸무게','지점']]
# Out:
#      담당  몸무게   지점
# 회차
# 4   최재우  NaN  여의도
# 7   최재우  NaN  여의도
# 8   김민철  NaN  여의도

# %%
data[data['몸무게'].notnull()]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data.loc[~data['몸무게'].isnull(),['담당','몸무게','지점']]

# 물결 = NOT
# Out:
#      담당   몸무게   지점
# 회차
# 1   김지수  76.4   강남
# 2   김지수  75.7   강남
# 3   김지수  76.0   강남
# 5   김지수  76.2  강남구
# 6   최재우  75.7  여의도
# 9   김민철  75.0  여의도

# %%
data.loc[data['몸무게'].notnull(),['담당','몸무게','지점']]
# Out:
#      담당   몸무게   지점
# 회차
# 1   김지수  76.4   강남
# 2   김지수  75.7   강남
# 3   김지수  76.0   강남
# 5   김지수  76.2  강남구
# 6   최재우  75.7  여의도
# 9   김민철  75.0  여의도

# %% [markdown]
# ## 기본 기능

# %%
data['몸무게'].mean()
# Out:
# 75.83333333333333

# %%
data['몸무게'].max()
# Out:
# 76.4

# %%
data['몸무게'].min()
# Out:
# 75.0

# %%
data['몸무게'].notnull()
# Out:
# 회차
# 1     True
# 2     True
# 3     True
# 4    False
# 5     True
# 6     True
# 7    False
# 8    False
# 9     True
# Name: 몸무게, dtype: bool

# %%
data[data['몸무게'].notnull()]
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도

# %%
data.shape
# Out:
# (9, 6)

# %% [markdown]
# ## 행렬 추가/수정

# %%
data.head()
# Out:
#      이름         측정일   몸무게  단위   담당   지점
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남
# 2   강성희  2019-01-02  75.7  kg  김지수   강남
# 3   강성희  2019-01-03  76.0  kg  김지수   강남
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구

# %%
data['날씨'] = '나쁨'

data
# Out:
#      이름         측정일   몸무게  단위   담당   지점  날씨
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남  나쁨
# 2   강성희  2019-01-02  75.7  kg  김지수   강남  나쁨
# 3   강성희  2019-01-03  76.0  kg  김지수   강남  나쁨
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도  나쁨
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구  나쁨
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도  나쁨
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도  나쁨
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도  나쁨
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도  나쁨

# %%
data ['결제여부'] = ['True','False','True','True','True','True','false','True','True']
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점  날씨   결제여부    과체중
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남  나쁨   True   True
# 2   강성희  2019-01-02  75.7  kg  김지수   강남  나쁨  False   True
# 3   강성희  2019-01-03  76.0  kg  김지수   강남  나쁨   True   True
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도  나쁨   True  False
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구  나쁨   True   True
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도  나쁨   True   True
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도  나쁨  false  False
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도  나쁨   True  False
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도  나쁨   True  False

# %%
data['과체중'] = (data['몸무게']>75.5)
data
# Out:
#      이름         측정일   몸무게  단위   담당   지점  날씨  결제여부    과체중
# 회차
# 1   강성희  2019-01-01  76.4  kg  김지수   강남  나쁨  True   True
# 2   강성희  2019-01-02  75.7  kg  김지수   강남  나쁨  True   True
# 3   강성희  2019-01-03  76.0  kg  김지수   강남  나쁨  True   True
# 4   강성희  2019-01-04   NaN  kg  최재우  여의도  나쁨  True  False
# 5   강성희  2019-01-05  76.2  kg  김지수  강남구  나쁨  True   True
# 6   강성희  2019-01-06  75.7  kg  최재우  여의도  나쁨  True   True
# 7   강성희  2019-01-07   NaN  kg  최재우  여의도  나쁨  True  False
# 8   강성희  2019-01-08   NaN  kg  김민철  여의도  나쁨  True  False
# 9   강성희  2019-01-09  75.0  kg  김민철  여의도  나쁨  True  False

# %% [markdown]
# # 행 추가하기, 열 삭제하기 => 과제

# %%
drop_columns = ['측정일', '단위']
data.drop(drop_columns, 1)
# Out:
#      이름   몸무게   담당   지점  날씨   결제여부    과체중
# 회차
# 1   강성희  76.4  김지수   강남  나쁨   True   True
# 2   강성희  75.7  김지수   강남  나쁨  False   True
# 3   강성희  76.0  김지수   강남  나쁨   True   True
# 4   강성희   NaN  최재우  여의도  나쁨   True  False
# 5   강성희  76.2  김지수  강남구  나쁨   True   True
# 6   강성희  75.7  최재우  여의도  나쁨   True   True
# 7   강성희   NaN  최재우  여의도  나쁨  false  False
# 8   강성희   NaN  김민철  여의도  나쁨   True  False
# 9   강성희  75.0  김민철  여의도  나쁨   True  False
